# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
import json, tweepy, requests, re, string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import nltk

# %%
with open("token.json")as f:
  tokens = json.load(f)

bearer_token = tokens['bearer_token']
api_key = tokens['api_key']
api_key_secret = tokens['api_key_secret']
access_token = tokens['access_token']
access_token_secret = tokens['access_token_secret']

auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
search_words = "gempa"
new_search = search_words + " -filter:retweets"
date = '2022-01-26'

# %% [markdown]
# Dikarenkan banyaknya gemapa yang terjadi akhir akhir ini sehingga membuat topik gempa menjadi banyak dibicarakan oleh orang baik di media sosial, media massa, maupun pada saat melakukan interaksi langsung.
# Dikarenakan alasan yang sebelumnya maka dari itu disini ingin mendapatkan informasi tentang apa saja yang dibicarakan dari topik gempa tersebut

# %%
tweets = tweepy.Cursor(api.search_tweets,
        q=new_search,
        lang="id",
        until = date).items(2000)

items = []
for tweet in tweets:
    items.append (tweet.text)

df = pd.DataFrame(data=items, columns=['tweet'])
df.to_csv('gempa_tweet.csv', index=False) 
df
# Out:
#                                                   tweet
# 0     @cattleyaishmn Halo, saya Bencana Bot. Untuk m...
# 1     Tbh kadang gue mikir pindah ibu kota tuh krn s...
# 2     Bisa ngga sih Tweet nya jangan info gempa teru...
# 3     Selamat pagii Sarapan roti boy dan white coffe...
# 4     @AdamPrakoso17 Gempa ora?\n\nInnalillahi \nAlh...
# ...                                                 ...
# 1995                                     woiii gempa :(
# 1996                         @raijull Lu ga gempa bang?
# 1997                      @noonauni_ptg gempa dimana? 🥺
# 1998                      @dnxvx lah iya ternyata gempa
# 1999  @RoseValidio Halo, saya Bencana Bot. Untuk mel...
#
# [2000 rows x 1 columns]

# %%
df = pd.read_csv('gempa_tweet.csv')

df['clean_tweet'] = df['tweet']

def case_folding(text):
    text = text.lower()
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    text = text.encode('ascii', 'replace').decode('ascii')
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    text = text.replace("http://", " ").replace("https://", " ")
    text = re.sub(r"\d+", "", text)
    text = text.translate(str.maketrans("","",string.punctuation))
    text = text.strip()
    text = re.sub('\s+',' ',text)
    return re.sub(r"\b[a-zA-Z]\b", "", text)

slang_list =[
    ("yg","yang"),
    ("gue","saya"),
    ("km",""),
    ("jan","januari"),
    ("mag","magnitudo"),
    ("lok","lokasi"),
    ("kalo","kalau"),
    ("lu","kamu"),
    ("ls",""),
    ("kedlmn","kedalaman"),
    ("goyang","berguncang"),
    ("sr",""),
    ("pas","saat"),
    ("boboiboy",""),
    ("udah","sudah"),
    ("gua","saya"),
    ("ngerasa","berasa"),
    ("kayak","seperti"),
    ("bgt","sangat"),
    ("banget","sangat"),
    ("sulsel","sulawesi selatan"),
    ("dah","sudah"),
    ("kek","seperti"),
    ("dikit","sedikit"),
    ("da",""),
    ("tp","tapi"),
    ("gw","saya"),
    ("sampe","sampai"),
    ("lg","lagi"),
    ("kemaren","kemarin"),
    ("dikit","sedikit"),
    ("kena","terkena"),
    ("baratdaya","barat daya"),
    ("klo","kalau"),
    ("ni","ini"),
    ("emang","memang"),
    ("gitu","seperti itu"),
    ("geter","bergetar"),
    ("emang","memang"),
    ("eh",""),
    ("mulu","selalu"),
    ("kenceng","kencang"),
    ("abis","habis"),
    ("ngerasain","merasakan"),
    ("deh",""),
    ("bener","benar"),
    ("gk","tidak"),
    ("wkwk",""),
    ("jg","juga"),
    ("kerasa","terasa"),
    ("gimana","bagaimana"),
    ("gede","besar"),
    ("dr","dari"),
    ("geser","bergeser"),
    ("gara",""),
    ("kak",""),
    ("kirain",""),
    ("dgn","dengan"),
    ("pd","pada"),
    ("trs",""),
    ("trus",""),
    ("lo","kamu"),
    ("ngga","tidak"),
    ("kebangun","terbangun"),
    ("org","seseorang"),
    ("roboh","rubuh"),
    ("doang","saja"),
    ("kaget","terkejut"),
    ("stay","tetap"),
    ("liat","lihat"),
    ("sm","sama"),
    ("tu",""),
    ("baratlaut","barat laut"),
    ("karna","karena"),
    ("jepun","jepang"),
    ("udh","sudah"),
    ("safe","aman"),
    ("oleng",""),
    ("halu",""),
    ("emg","emang"),
    ("kmrn","kemarin"),
    ("candiqqdotnet",""),
    ("link",""),
    ("skrg","sekarang"),
    ("semalem","semalam"),
    ("nanya","bertanya"),
    ("gini","begini"),
    ("yaa","ya"),
    ("keknya","sepertinya"),
    ("dlm","dalam"),
    ("oh",""),
    ("hah",""),
    ("ikn",""),
    ("puyeng","pusing"),
    ("ki",""),
    ("yaallah",""),
    ("ku","saya"),
    ("bentar","sebentar"),
    ("malem","malam"),
    ("anying",""),
    ("anjay",""),
    ("bgttt","sangat"),
    ("krasa","terasa"),
    ("gmn","gimana"),
    ("ko",""),
    ("loh",""),
    ("gak","tidak"),
    ("kwangya",""),
    ("gegara","karena"),
    ("tuh",""),
    ("tbh","sejujurnya"),
    ("pagii","pagi"),
    ("belom","belum"),
    ("krna","karena"),
    ("thn","tahun"),
    ("wkwkwk",""),
    ("aja","saja"),
    ("sih",""),
    ("jd","jadi"),
    ("bt","buat"),
    ("blm","belum"),
    ("grgr","gara gara"),
    ("tdk","tidak"),
    ("pdhl","padahal"),
    ("ehhh",""),
    ("diem","diam"),
    ("ama","dengan"),
    ("btw",""),
    ("tbtb","tiba tiba"),
    ("tdi","tadi"),
    ("temen","teman"),
    ("mikir","berpikir"),
    ("kadang","terkadang"),
    ("kmaren","kemarin"),
    ("ora","tidak"),
    ("mung","hanya"),
    ("atos","keras"),
    ("poll","sangat"),
    ("semooga","semoga"),
    ("kam",""),
    ("gilira","giliran"),
    ("gledek","geledek"),
    ("syg",""),
    ("liattanya","lihatnya"),
    ("inget","ingat"),
    ("serem","seram"),
    ("yaaa","ya"),
    ("iyaa","ya"),
    ("aamiin","amin"),
    ("solat","sholat"),
    ("anjir",""),
    ("emang","memang"),
    ("kyk","seperti") 
]

def slang_cleaner(text, slang_list:list=[]):
    word_token = word_tokenize(text)
    word_list=[]
    
    for word in word_token:
        for slang in slang_list:
            if word.lower() in slang[0].lower():
                word = slang[1]
                break
        word_list.append(word)
        
    text =' '.join(word_list)
    return text

def tokenizing(text):
    text = word_tokenize(text)
    return text

def stopword_cleaner(data):
    sw_indonesia = stopwords.words("indonesian")
    data  = [word for word in data if word not in sw_indonesia]
    data = ' '.join(data)
    return data

df['clean_tweet'] = df['clean_tweet'].apply(lambda x: case_folding(x))
df['clean_tweet'] = df['clean_tweet'].apply(lambda x: slang_cleaner(x, slang_list))
df['clean_tweet'] = df['clean_tweet'].apply(lambda x: tokenizing(x))
df['clean_tweet'] = df['clean_tweet'].apply(lambda x: stopword_cleaner(x))

# %%
#Distribusi Frekuensi Jumlah Karakter per Data
bin_range = np.arange(0, 260, 10)
df['clean_tweet'].str.len().hist(bins=bin_range)
plt.show()

#Distribusi Frekuensi Jumlah Kata per Data
bin_range = np.arange(0, 50)
df['clean_tweet'].str.split().map(lambda x: len(x)).hist(bins=bin_range)
plt.show()

#Distribusi Frekuensi Panjang Kata Rata-Rata Pada Data
df['clean_tweet'].str.split().apply(lambda x : [len(i) for i in x]).map(lambda x: np.mean(x)).hist()
plt.show()

#Distribusi Frekuensi Kata
query = df['clean_tweet'].apply(lambda x: word_tokenize(str(x)))
clean_tweet = [word for tweet in query for word in tweet]
fqdist = FreqDist(clean_tweet)
print(fqdist)
print('  ')
most_common_word = fqdist.most_common(300)
print(most_common_word)
print('  ')
fqdist.plot(20,cumulative=False)
plt.show()

#Distribusi Bigram
result = pd.Series(nltk.ngrams(clean_tweet, 2)).value_counts()[:20]
print(result)
# Out:
# C:\Users\steve\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\steve\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# <FreqDist with 3301 samples and 13117 outcomes>
#
# [('gempa', 1948), ('terkadang', 388), ('berguncang', 374), ('lombok', 279), ('bencana', 170), ('dampak', 164), ('halo', 158), ('melaporkan', 156), ('sekitarmu', 156), ('bot', 155), ('silakan', 155), ('balas', 155), ('terbangun', 134), ('pagi', 113), ('bumi', 97), ('barat', 90), ('subuh', 89), ('tidur', 85), ('magnitudo', 82), ('berasa', 78), ('daya', 73), ('kedalaman', 69), ('aman', 66), ('januari', 65), ('dimana', 58), ('info', 56), ('merasakan', 54), ('bmkg', 53), ('kemarin', 51), ('tsunami', 51), ('trauma', 51), ('sholat', 50), ('ya', 50), ('semoga', 47), ('bali', 46), ('terkejut', 46), ('update', 46), ('beneran', 45), ('jam', 45), ('barusan', 44), ('guncang', 41), ('dibangunin', 41), ('orang', 40), ('langsung', 39), ('habis', 38), ('mengguncang', 32), ('min', 32), ('lokasi', 31), ('tau', 30), ('takut', 29), ('susulan', 29), ('lari', 29), ('rumah', 29), ('mataram', 29), ('mimpi', 28), ('teman', 27), ('banten', 27), ('kali', 27), ('selasa', 25), ('pusat', 25), ('panik', 24), ('terkena', 24), ('semalam', 24), ('wib', 23), ('wita', 23), ('mamuju', 23), ('pusing', 22), ('gara', 22), ('ntb', 22), ('daerah', 21), ('bikin', 20), ('diguncang', 20), ('berkekuatan', 19), ('kepala', 19), ('warga', 19), ('kencang', 19), ('bangunin', 18), ('gunung', 18), ('lumayan', 18), ('korban', 18), ('lihat', 18), ('darat', 18), ('nih', 17), ('badan', 17), ('laut', 17), ('selatan', 17), ('bangunan', 17), ('vertigo', 16), ('jakarta', 16), ('indonesia', 16), ('terdampak', 16), ('buka', 16), ('haiti', 16), ('lapas', 16), ('pekerjaan', 16), ('kasur', 15), ('hati', 15), ('panas', 15), ('akibat', 15), ('perempuan', 15), ('kemenkumham', 15), ('terima', 15), ('tenggara', 15), ('getaran', 14), ('mandi', 14), ('pulau', 14), ('kah', 14), ('tumben', 14), ('alarm', 14), ('hasil', 14), ('rehabilitasi', 14), ('majenemamuju', 14), ('kamar', 14), ('gemeteran', 13), ('hatiku', 13), ('bergeser', 13), ('pake', 13), ('wilayah', 13), ('keinget', 13), ('berpikir', 12), ('pandeglang', 12), ('bergetar', 12), ('sumpah', 12), ('jepang', 12), ('jawa', 12), ('masjid', 12), ('tewas', 12), ('sebentar', 11), ('suka', 11), ('kucing', 11), ('pasca', 11), ('tremor', 11), ('kelas', 11), ('dom', 11), ('berita', 10), ('innalillahi', 10), ('alhamdulillah', 10), ('alam', 10), ('dirasakan', 10), ('lantai', 10), ('diam', 10), ('taunya', 10), ('gempanya', 10), ('twitter', 9), ('amin', 9), ('pantes', 9), ('nggak', 9), ('asli', 9), ('kejadian', 9), ('masi', 9), ('iii', 9), ('diperbaiki', 9), ('berhamburan', 9), ('rubuh', 9), ('untung', 9), ('anak', 9), ('tpi', 9), ('pusatnya', 9), ('nyawa', 9), ('potensi', 8), ('cari', 8), ('lempengan', 8), ('merapi', 8), ('suara', 8), ('megathrust', 8), ('gedung', 8), ('rampung', 8), ('sulbar', 8), ('rusak', 8), ('dmn', 8), ('keras', 7), ('masuk', 7), ('makan', 7), ('segini', 7), ('engga', 7), ('mengalami', 7), ('pintu', 7), ('kayaknya', 7), ('cek', 7), ('gatau', 7), ('kabupaten', 7), ('teriak', 7), ('kayanya', 7), ('capek', 7), ('detik', 7), ('sulawesi', 7), ('bilang', 7), ('nangis', 7), ('video', 7), ('story', 7), ('siang', 7), ('cerita', 7), ('baca', 7), ('mantan', 7), ('negara', 7), ('lpp', 7), ('pupr', 7), ('kemenk', 7), ('tetep', 7), ('kuat', 7), ('gemeter', 7), ('minggu', 7), ('yaudah', 7), ('huhu', 7), ('cepet', 6), ('infonya', 6), ('selamat', 6), ('denpasar', 6), ('sesar', 6), ('berpotensi', 6), ('tolong', 6), ('saudara', 6), ('pantesan', 6), ('namanya', 6), ('muncul', 6), ('news', 6), ('coba', 6), ('sadar', 6), ('turun', 6), ('aneh', 6), ('sakit', 6), ('posisi', 6), ('dunia', 6), ('serius', 6), ('loncat', 6), ('jgn', 6), ('kakak', 6), ('cuaca', 6), ('batu', 6), ('sunda', 6), ('timur', 6), ('astaghfirullah', 6), ('keluarga', 6), ('main', 6), ('selesai', 6), ('auto', 6), ('lokal', 6), ('updatenya', 6), ('tektonik', 6), ('lt', 6), ('dangkal', 6), ('foto', 6), ('susah', 6), ('anaknya', 6), ('nusa', 6), ('dimanaa', 6), ('status', 6), ('ekspresi', 6), ('khofifah', 6), ('shubuh', 6), ('mobil', 6), ('astagfirullah', 6), ('perasaan', 6), ('subuhan', 6), ('mj ...
# (dampak, gempa)         160
# (halo, bencana)         155
# (gempa, sekitarmu)      155
# (silakan, balas)        155
# (sekitarmu, silakan)    155
# (bencana, bot)          155
# (melaporkan, dampak)    155
# (bot, melaporkan)       155
# (terkadang, gempa)      153
# (gempa, gempa)          109
# (gempa, lombok)          95
# (gempa, berguncang)      89
# (barat, daya)            73
# (gempa, bumi)            71
# (lombok, gempa)          53
# (gempa, magnitudo)       47
# (berguncang, gempa)      46
# (terbangun, gempa)       46
# (gempa, dimana)          45
# (info, gempa)            42
# dtype: int64

# %%
#Lakukan Sentiment Analysis 

hasil = []
pos_list= open("./kata_positif.txt","r")
pos_kata = pos_list.readlines()
neg_list= open("./kata_negatif.txt","r")
neg_kata = neg_list.readlines()  
list_anti = ['tidak','lawan','anti', 'belum', 'belom', 'tdk', 'jangan', 'gak', 'enggak', 'bukan', 'sulit', 'tak', 'sblm']

items = df['clean_tweet'].values.tolist()

for item in items:
    print(item.strip())
    tweets = item.strip().split() #tokenization
    # print(tweets)
    count_p = 0 #nilai positif
    count_n = 0 #nilai negatif
    
    for tweet in tweets:
        for kata_pos in pos_kata:
            if kata_pos.strip().lower() == tweet.lower():
                if items[items.index(item)-1] in list_anti:
                    print(items[items.index(item)-1], kata_pos, ['negatif'])
                    count_n += 1
                else:
                    print(kata_pos, ['positif'])
                    count_p += 1
        for kata_neg in neg_kata:
            if kata_neg.strip().lower() == tweet.lower():
                if items[items.index(item)-1] in list_anti:
                    print(items[items.index(item)-1], kata_neg, ['positif'])
                    count_p += 1
                else:
                    print(kata_neg, ['negatif'])
                    count_n += 1
    
    print ("positif: "+str(count_p))
    print ("negatif: "+str(count_n))
    hasil.append(count_p - count_n)
    print ("-----------------------------------------------------")
    
print ("Nilai rata-rata: "+str(np.mean(hasil)))
print ("Standar deviasi: "+str(np.std(hasil)))
# Out:
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# sejujurnya terkadang berpikir pindah kota sebenernya pemerintah tau potensi gempa cepet
# potensi
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# tweet info gempa sekalikali infonya berguncang bikin orang bahagia
# gempa
#  ['negatif']
# bahagia
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# selamat pagi sarapan roti terkadang white coffe scroll twitter terkadang berita gempa takut kemarin denpasar
# selamat
#  ['positif']
# gempa
#  ['negatif']
# takut
#  ['negatif']
# positif: 1
# negatif: 2
# -----------------------------------------------------
# gempa innalillahi alhamdulillah aman keras
# gempa
#  ['negatif']
# alhamdulillah
#  ['positif']
# aman
#  ['positif']
# positif: 2
# negatif: 1
# -----------------------------------------------------
# tsunami semoga sehat amin berguncang
# tsunami
#  ['negatif']
# semoga
#  ['positif']
# sehat
#  ['positif']
# sehat
#  ['positif']
# positif: 3
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# berguncang penyebabnya gempa bencana alam terkadang kaitannya azab kaum berguncang beriman
# gempa
#  ['negatif']
# bencana
#  ['negatif']
# beriman
#  ['positif']
# positif: 1
# negatif: 2
# -----------------------------------------------------
# merasakan gempa kemarin berasa ngiranya vertigo kambuh giliran
# gempa
#  ['negatif']
# kambuh
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# gemeteran berguncang gempa getaran hatiku berguncang merindukanmu yor teensyori
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# berguncang pikir gempa emun mandi mandi kasur
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# bangunin subuh gempa ujan geledek
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa lombok selasa januari pkl wib kemarin pagi memiliki mekanisme sumber sesar bergeser mengiri
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa lombok selasa januari pkl wita kemarin berguncang mengguncang pulau lombok menyeb
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa bumi semenit sebentar
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# terkadang gempa terkadang info masuk terkadang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# kasur berguncang berguncang gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# trust issue gempa periksa barang lihatnya orang gempa makannya
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# jalur sesar berguncang pemicu gempa lombok selasa januari pkl wita terkadang teman
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# perbuatan dosa kemaksiatan meraja lela tunggu bencana berguncang besarmungk
# dosa
#  ['negatif']
# kemaksiatan
#  ['negatif']
# bencana
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# salah satunya paham borok partai dipecat gempa partai terkadang remnya
# salah
#  ['negatif']
# borok
#  ['negatif']
# dipecat
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 4
# -----------------------------------------------------
# gempa disertai tsunami berpotensi pandeglang bmkg tolong muspika aktif
# gempa
#  ['negatif']
# tsunami
#  ['negatif']
# aktif
#  ['positif']
# positif: 1
# negatif: 2
# -----------------------------------------------------
# berasa bumi bergetar terkadang gempa trutama bebaring gaterlalu parah
# gempa
#  ['negatif']
# parah
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# gempa terkadang berguncang mengguncang hatiku nadilajkt
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# mimpi gempa pertanda cari google ambigu
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# ahahahha tiduran gempa kemarin tau gempa beneran
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# tsunami semoga saudara saudari lindungan swt amin
# tsunami
#  ['negatif']
# semoga
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# info karangetang periode wita mm secx vta mm sp sec sec
# positif: 0
# negatif: 0
# -----------------------------------------------------
# vertigo pantesan suka berasa terkadang gempa
# suka
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# info gempa magnitudo januari wit lokasi barat daya namleaburu utara namr
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# gempa berguncang dirasakan jakarta januari publik
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# kemarin ngalamin kemarin stres berat makan benda gerak
# stres
#  ['negatif']
# makan
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# teensfannie lempengan bumi berguncang bergeser hati
# positif: 0
# negatif: 0
# -----------------------------------------------------
# yanti halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# dipasang gempa khawatir merambat kemanamana cepatcepat dilokalisir
# gempa
#  ['negatif']
# khawatir
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# gempa terkadang berguncang mengguncang hatiku
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# merem berasa berguncang panik gempa terbangun terkadang kabur nih
# panik
#  ['negatif']
# gempa
#  ['negatif']
# kabur
#  ['negatif']
# kabur
#  ['negatif']
# positif: 0
# negatif: 4
# -----------------------------------------------------
# terbangun jam segini takut gempa kemarin huhuu
# takut
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# sumpah parnoan gempa tinggal apart skdjnsksksksk subuh giniiii
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# magnitudo januari wib lokasi pusat gempa otak kyra kedalaman
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# barusan gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# urgent secepatnya pemindahan asn pemerintah kedalaman gempa megat
# urgent
#  ['negatif']
# secepatnya
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 2
# -----------------------------------------------------
# begadang nunggu info gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# michristychibi lempengan bumi berguncang bergeser hati
# positif: 0
# negatif: 0
# -----------------------------------------------------
# nikmati kemenangan langsung daftar idnya berguncang
# kemenangan
#  ['positif']
# positif: 1
# negatif: 0
# -----------------------------------------------------
# pusing gempa
# pusing
#  ['negatif']
# pusing
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# gempa kah
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# badan bergetar kukira gempa overdosis kopi maem gasayang terkadang berguncang januari
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# barusan gempa awak oyong
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# namanya vertigo berguncang berasa gempa muncul tiduranrebahan
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# dandim pdg hadiri kegiatan sosialisasi informasi gempa bumi dantsunami
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# sumpaah gempa terbangun
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# tsunami membangunkan utk sholat subuh
# tsunami
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# banten gempa jakarta
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# barusan gempa berguncang terbangun
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa cari nemu
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# tsunami berguncang smoga engkau lindungi rakyat indonesia
# tsunami
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa kah
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# semoga tidur parno gempa
# semoga
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# berguncang pantes jakarta berasa gempa barusan
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# info gempa magnitudo januari wib lokasi barat daya bayahbanten kedalaman
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# tidur terbangun serasa gempa engga berguncang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa terkadang berguncang mengguncang hatiku
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# tumben peka gempa mah molorr tidurr ngrasain apapun
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gunung merapi mengalami kali gempa guguran okezone news
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa berguncang kecapean
# gempa
#  ['negatif']
# kecapean
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# duhh semoga terkadang gempa susulan ya aman
# semoga
#  ['positif']
# gempa
#  ['negatif']
# aman
#  ['positif']
# positif: 2
# negatif: 1
# -----------------------------------------------------
# berguncang berasa gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# rebahan berasa berguncang gempa melayang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# benerrr ponakananku ngobrolnya bagus arah terkadang inisiatif lihatnya ajak
# bagus
#  ['positif']
# inisiatif
#  ['positif']
# positif: 2
# negatif: 0
# -----------------------------------------------------
# problematika tidur kunci pintu nggak berguncang dikunci terkadang gempa ribet keluarnya
# problematika
#  ['negatif']
# gempa
#  ['negatif']
# ribet
#  ['negatif']
# ribet
#  ['negatif']
# positif: 0
# negatif: 4
# -----------------------------------------------------
# merem berguncang getaran gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# ya samaa nyari berita bnrn gempa engga terkadang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# pagi lombok gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# sumpahh gempa pagi takut tidur
# gempa
#  ['negatif']
# takut
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# gunung merapi mengalami kali gempa guguran gunung merapi perbatasan yo
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# apapun barat daya gempa gasi tidur terbangun berguncang woi
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gunung merapi mengalami kali gempa guguran gunung merapi perbatasan yo
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# barusan gempa kah
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# enyax gempa sun
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa mengguncang terbitlah insomniaaa hadeuuh
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa bumi duga diatas merasakan berguncang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# asli badan berguncang berasanya gempa muku berguncang asli after effectnya gaselese vertigo berguncang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa akwowkwowk
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa berguncang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# jepang habis dilanda gempa hebat reaktor nuklirnya bocor
# dilanda
#  ['negatif']
# gempa
#  ['negatif']
# hebat
#  ['positif']
# bocor
#  ['negatif']
# positif: 1
# negatif: 3
# -----------------------------------------------------
# ngerti vertigo semoga chat dika gempa anjirrr lari
# semoga
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# mbuh ambles mbuh mungah tanah barat laut seng nang titik iku gempa merubah volumewadah tempatnya air
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# kayaknya notifku muncul gempa semiga ya
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# gempa berguncang terkadang pertiwi
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# owner tmpt krja kedalaman namanya dude alias desember tanggal lahirnya terkadang teman
# positif: 0
# negatif: 0
# -----------------------------------------------------
# gempa kemarin ngeh gempa kumat
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# awas gempa
# awas
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# tsunami berasa sebanding mas ringroad kulon neg mbengi earth hour
# tsunami
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# sch jago olahraga disinii butuh teman ngoreksi latihan pjok trivia epis
# jago
#  ['positif']
# jago
#  ['positif']
# positif: 2
# negatif: 0
# -----------------------------------------------------
# paranoid tidur berasa terkadang gempa
# paranoid
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# pagi gempa hujan double kill
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# mental gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# astaga kayaknya kecapean coba cek google daerahmu gempa
# kecapean
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# gatau gempa kecapean
# gempa
#  ['negatif']
# kecapean
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# gempa sugesti digoyangingoyangin
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# lho gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa efek kecapean
# gempa
#  ['negatif']
# kecapean
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gemuruhnya bikin bergetar gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa patah lithosphere selatan kedalaman utara
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# anjr skg parno kasur berguncang gara gara kucing ngiranya gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# barat daya pagi gempa subuh suara gemuruh hnti bikin takut tdur besok piket pagi
# gempa
#  ['negatif']
# takut
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# tau mimpi beneran gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa hyung
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa sadar
# gempa
#  ['negatif']
# sadar
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# barusan gempa halusinasiku
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# demam ngigau gempa terkadang diketawain kosan
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gunung merapi alami kali gempa guguran news bengkulu
# alami
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# habis gempa mall chill pesen makan
# gempa
#  ['negatif']
# makan
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# ya gempa suka pusing gempa beneran
# gempa
#  ['negatif']
# suka
#  ['positif']
# pusing
#  ['negatif']
# pusing
#  ['negatif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# ya ners gempa suka panik vertigo kambuh gimana berguncang kambuh ngeri bsa
# gempa
#  ['negatif']
# suka
#  ['positif']
# panik
#  ['negatif']
# kambuh
#  ['negatif']
# kambuh
#  ['negatif']
# ngeri
#  ['negatif']
# positif: 1
# negatif: 5
# -----------------------------------------------------
# kabupaten lombok barat daya ntb diguncang gempa berkekuatan selasa subuh getaran gempa kedalaman denpasar
# diguncang
#  ['negatif']
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# tsunami semoga
# tsunami
#  ['negatif']
# semoga
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# tsunami semoga
# tsunami
#  ['negatif']
# semoga
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# berguncang yat naudzubillah mindzalik jakarta terkena gempa megathrust tsunami
# gempa
#  ['negatif']
# tsunami
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# kalimantan sebutan pulaunya pulaunya bergerak maksudmu terkadang gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# jujur gempa subuh barat daya takut tidur kamarku posisinya pintu rumah
# jujur
#  ['positif']
# jujur
#  ['positif']
# gempa
#  ['negatif']
# takut
#  ['negatif']
# positif: 2
# negatif: 2
# -----------------------------------------------------
# anakkolong alhamdulillah berfoto sudut jalan pasca gempa lombok
# alhamdulillah
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# wind halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# yaampuun beneran kejadian kemarin gempa sempet berpikir vertigo kambuh sadar teman teriak gem
# gempa
#  ['negatif']
# kambuh
#  ['negatif']
# sadar
#  ['positif']
# positif: 1
# negatif: 2
# -----------------------------------------------------
# turun tangganya hatihati dorong bawa hp lari kayanya diulang kali terkadang
# turun
#  ['negatif']
# dorong
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# gempa gatau badan suka berguncang capek kyknya
# gempa
#  ['negatif']
# suka
#  ['positif']
# capek
#  ['negatif']
# capek
#  ['negatif']
# positif: 1
# negatif: 3
# -----------------------------------------------------
# wejangan mama gempa subuh tidur pake singlet langsung nelpon terkadang apaapa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# sumpah gempa guenya berguncang sumpah berguncang muter
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# aneh berasa gempa
# aneh
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# sosialisasi informasi gempa bumi terkadang tsunami kabupaten pandeglang selasa januari
# gempa
#  ['negatif']
# tsunami
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# berdiri kerja terkadang suka berasa berguncang rebahan jepang ya semenjak gempa januari
# kerja
#  ['positif']
# suka
#  ['positif']
# gempa
#  ['negatif']
# positif: 2
# negatif: 1
# -----------------------------------------------------
# gempa pagi detik degdegannya
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# terkadang gempa berguncang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# info gempa magnitudo januari wita lokasi barat laut morowalisulteng kedalaman
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# tsunami semoga sodara sodara snah
# tsunami
#  ['negatif']
# semoga
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# stress berat berasa gempa kepala muter sakit
# gempa
#  ['negatif']
# sakit
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# menyebabkan gempa megatras pulau jawa semoga amin
# gempa
#  ['negatif']
# semoga
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# gempa bumi south sandwich islands region sulawesi selatan januari utc wib menit berguncang merasakan
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# lumayan terkadang gempa darah rendah kyknya inimah
# gempa
#  ['negatif']
# rendah
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# asap berwarna putih gunung merapi ketinggian meter
# positif: 0
# negatif: 0
# -----------------------------------------------------
# gempa pusing maaf
# gempa
#  ['negatif']
# pusing
#  ['negatif']
# pusing
#  ['negatif']
# maaf
#  ['positif']
# positif: 1
# negatif: 3
# -----------------------------------------------------
# gempa terkadang berguncang mengguncang hatiku steffychibi
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# rahmad
# positif: 0
# negatif: 0
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# gempa siiiiiiih
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# banten terkadang pmi kota pandeglang kebutuhan berguncang pemulihan pasca bencana gempa bumi tim
# bencana
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# peninjauan terkadang survey terkait dampak bencana gempa bumi pandeglang tim berangkat markas pm
# dampak
#  ['negatif']
# bencana
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# tim assessment pmi dki survei dampak gempa pandeglang banten kepala markas pmi provinsi dki jakarta edwar bach
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# gempa pagi petirnya semalam berasa extra seram gabisa tidur beneran
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# kocag sekantor vaksin booster bareng meriang semalam pagi jam januari
# positif: 0
# negatif: 0
# -----------------------------------------------------
# warga terdampak gempa bumi lumajang terimahuntap
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa lantai pasrah ajah
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# pov record tremor gempa bumi
# tremor
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# panas hawanya berguncang mudahan gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# kemarin tidur gempa trnyata ketempelan
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# pemerintah duduk diam terkadang perhatian kemunculan syndrome
# perhatian
#  ['positif']
# positif: 1
# negatif: 0
# -----------------------------------------------------
# pantesan makan goyanggoyang pusing taunya gempa bingung
# makan
#  ['positif']
# pusing
#  ['negatif']
# pusing
#  ['negatif']
# gempa
#  ['negatif']
# bingung
#  ['negatif']
# bingung
#  ['negatif']
# positif: 1
# negatif: 5
# -----------------------------------------------------
# berasa kewaspadaan berubah takut terkadang was terkadang goyangan berguncang
# takut
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# contoh code scrapping web bmkg
# positif: 0
# negatif: 0
# -----------------------------------------------------
# gempa beneran situ ngrasain coba cek searching gempa muncul tweet
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# gempa lantai gempa lantai gempa lantai terkadang rebahan terkadang satupun terkadang heboh
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# terkena gempa syndrome
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa keleyengan makan
# gempa
#  ['negatif']
# makan
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# tolong dibaca ulang bilang ngira gempa gempa
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# info gempa bumi bmkg lombok terkadang mataram bali
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# barusan ngrasain posisi duduk bangku cari info gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# bencana alam dunia januari gempa bumi jepang firenado argentina saluran bencana alam
# bencana
#  ['negatif']
# gempa
#  ['negatif']
# bencana
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# king halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# gempa detik hancurkan gujarat india tewaskan belasan ribu orang januari
# gempa
#  ['negatif']
# tewaskan
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# bekasi jabar mnt berasa berguncang detik januari serius cari info gempa muncul taiwan
# serius
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# gempa berasa konser keper
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# kepala pusing kayanya daritadi berasa gempa
# pusing
#  ['negatif']
# pusing
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# gaenak gempa lantai posisi diatas kasur loncat keseleo
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# flu habis tidur jam bangunbangun pusing ngira gempa ajdbdjdk
# pusing
#  ['negatif']
# pusing
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# gatau vertigo tdr ngrasa gempa kuenceng lgsg nangis manggil ortu
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa barusan
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# mesti tau semenjak gempa berasa berguncang kaga gempa
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# jam tidur kacau terbangun rebahan terkadang ganti posisi kepala aza serasa gempami
# kacau
#  ['negatif']
# kacau
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# otak jem nak terkena prank its really happening patutlah terkadang orang cakap
# cakap
#  ['positif']
# positif: 1
# negatif: 0
# -----------------------------------------------------
# mak aih gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# nih we cm kyak terkadang trauma gempa
# trauma
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# heeseung jgn senyum sebentar bikin gempa jabodetabek
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# bocil tidur terkadang gempa diam kemarin gempa melek tidur denger kreseks
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# barat daya pagi terkadang gempa kh
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# asli parnoan gara gara gempa pagi
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# trauma kejadian gempa bumi diculik berulangkali dibully kakak kelas sd smp kecelakaan
# trauma
#  ['negatif']
# gempa
#  ['negatif']
# kecelakaan
#  ['negatif']
# kecelakaan
#  ['negatif']
# positif: 0
# negatif: 4
# -----------------------------------------------------
# oarfish hewan barat laut berguncang dianggap pertanda gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# terkena gempa daerah situ kali berguncang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# ngagetin sii gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# bencana alam dunia januari gempa bumi jepang letusan gunung berapi turrialbacosta rica firen
# bencana
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# gempa berguncang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa badan gemeteran
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# bmkg sosialisasikan informasi potensi gempa bumi pandeglang banten
# potensi
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# lempengan bumi berguncang bergeser hati
# positif: 0
# negatif: 0
# -----------------------------------------------------
# kemarin gempa pahaku biru lebam gtu aq sadar taunya mandi habis
# gempa
#  ['negatif']
# sadar
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# record video unboxing album sf last lepass tengok pc fon berguncang gempa bumi
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa bermagnitudo berguncang banten selatan januari pembelajaran kes
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa terkadang berguncang mengguncang hatiku teenskikies
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa bumi
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# tipe orang berguncang bikin story coba cari hape berguncang terkadang gadget berguncang terkadang fitur ois terkadang eis sumpa
# positif: 0
# negatif: 0
# -----------------------------------------------------
# beasiswa tunas indonesia jepang tij upaya meringankan beban korban gempa jogja
# beasiswa
#  ['positif']
# meringankan
#  ['positif']
# korban
#  ['negatif']
# gempa
#  ['negatif']
# positif: 2
# negatif: 2
# -----------------------------------------------------
# semalam mimpiin mas crush paginya gempa pertanda
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# cuaca konsisten pagi dingin bangett gerimis siang cerahh secerah
# konsisten
#  ['positif']
# positif: 1
# negatif: 0
# -----------------------------------------------------
# kania halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# puncanya lembah klang padat sgt pembangunan highway brsilang perumahan terkadang tanah kosong jepang mmg pemaju
# padat
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# berguncang ngeringeri sedap atap jis ketinggian meter pekerjanya cerita gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa berguncang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa taunya keleyengan aowkaaowk
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# wkkw suka trust issue gempa
# suka
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# bes prediksi gempa mgathrust fake berguncang takut baca info palsu maaf
# gempa
#  ['negatif']
# takut
#  ['negatif']
# palsu
#  ['negatif']
# maaf
#  ['positif']
# positif: 1
# negatif: 3
# -----------------------------------------------------
# jalan bersimpangan tol pemkab klaten konstruksi tahan gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# kemarin semalam mimpi gempa kebiasaan cek twitter bmkg langsung cek terbangun terkadang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# masjid halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# bisabisanya jam pagi terkadang gempa lombok terbangun lihat info bmkg bali gempa berasa denpasar
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# trust issue gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# laen pingaku bbm hpny bergetar ping cinta berguncang bergetar gempa bumi teensyori
# cinta
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# asli gempa posisiku tengkurep lho berguncang berpikir badan berguncang ya masuk notif bmkg
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# muhaddith sayyid muhammad bin alwi maliki fatihah
# positif: 0
# negatif: 0
# -----------------------------------------------------
# gempa kantor panik asik youtubean dibunyiin alarm gempa wkwkwkwk
# gempa
#  ['negatif']
# panik
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# haha wajib terkadang terkadang gempa budak kucing terkena terkadang tapiii nak cari kat
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# terkadang menginformasikan gempa pagi lombok info cob
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# rekaman datangnya tsunami gempa kemarin jepang tsunami warning tsunami gel seti
# tsunami
#  ['negatif']
# gempa
#  ['negatif']
# tsunami
#  ['negatif']
# tsunami
#  ['negatif']
# positif: 0
# negatif: 4
# -----------------------------------------------------
# teman gempa berpikir gempa berguncang berguncang berguncang
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# heran make sure kedalaman orang terkadang gempa engga
# heran
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# pagi gempa siang panasss semalam ujan ding mantan cuman
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# seru terkadang panik habis terkadang gempa kalung bumbu dapur mind blowing
# panik
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# korban gempa bumi bupati lumajang letakkan batu pembangunanhuntap
# korban
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# sumber gempa dihatiku
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa prediksi napa muncul berita ginian
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# ohh ya aliran darah sekujur tubuh berdetak cepat berasa gempa
# aliran
#  ['negatif']
# cepat
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 2
# -----------------------------------------------------
# tidur sejam aktivitas jam pagi pantesan berasa gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa kemarin berasa rumahnya shaking tau kesel overthink
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# salah berguncang kayanya live terkadang peringatan gempa
# salah
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# gatau vertigo kerna takut cek dokter terkena covid berasa
# takut
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# terbangun tidur gempa terkena cahaya gempa terkena panas gempa terkejut gempa cape gempa
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# cape
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 6
# -----------------------------------------------------
# berwarna kayaknya tier ketiganya bayangin hali warnanya kemerahan blaze warnanya
# positif: 0
# negatif: 0
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# berguncang merasakan gempa pagi kabs
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# hambanya habis gempa tdr
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# jenat natama gempa natama beserta calon baby natama
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
#
# positif: 0
# negatif: 0
# -----------------------------------------------------
# aayy halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# suka trust issue gempa reminiscing lomba gempa
# suka
#  ['positif']
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 2
# -----------------------------------------------------
# pusing kebanyakan nanhis pusibg kays lago gempa
# pusing
#  ['negatif']
# pusing
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# ners tidur pakai bantal menyebabkan timbulnya vertigo berguncang ners
# positif: 0
# negatif: 0
# -----------------------------------------------------
# wilayah pesisir selatan kabupaten pandeglang banten tepatnya kecamatan sumur minim alatalat canggih berguncang
# minim
#  ['negatif']
# canggih
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# happy wedding qol terkadang swaber nuna wish berguncang cepet dap
# happy
#  ['positif']
# positif: 1
# negatif: 0
# -----------------------------------------------------
# gempa pusing
# gempa
#  ['negatif']
# pusing
#  ['negatif']
# pusing
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# rangka struktur terkadang pondasi memperhitungkan gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa kah
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# kukira gempa bumi berguncang mbliyut
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# seumuran scorpio hujan badai petir halilintar tsunami gempa bumi wakkk
# tsunami
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# alhamdulillahdulu gempa lombokana saksibagaimana manusia mulia berbaju
# gempa
#  ['negatif']
# mulia
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# berguncang gempa kuattanda sdh terkadang bsok energi bsr mnuju tgl sktrn selat sunda timur
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# terkena vertigo terkadang gempa kemarin besoknya vertigo habis sakit emang vertigo
# gempa
#  ['negatif']
# sakit
#  ['negatif']
# emang
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# aftershock ttg gempa bumi
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# menghijaukan hutan sabang marauke masuk youtuber hamim merasakan youtuber blok bumi beran
# menghijaukan
#  ['positif']
# positif: 1
# negatif: 0
# -----------------------------------------------------
# keinget koordinatorku gempa kemarin teriak gempa bilang kayaknya vertigo kambuh
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# kambuh
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# tau vertigopusing biasadarah rendahtapi pusing berguncang
# pusing
#  ['negatif']
# pusing
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# gempa barat laut banda kedalaman terkadang januari
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# ap lakukan mandi gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# ...
# update gempa bu astaga
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa dimana
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# beneran gempa berguncang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# kamar blkng jam segini dibanguninnya gempa sadar lngsng lari kedalaman
# gempa
#  ['negatif']
# sadar
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# met pagi berguncang terbangun alarm alam gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# beneran gempa cuman terbangun berasa gempa
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# gempa berasa kedalaman keinget gempa
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# gempa bali untung mandi awokawokawok kasian anak sekolahan berguncang terbangun terkejut
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# selesai salam terkadang suara angin dikittt wahh gempa nih terkadang beneran
# selesai
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# mntep gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa dimana
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# jam terkadang pagipagi loncat tidur gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# terbangun gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# jalan teriak ngantuk merasakan gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# info gempa dimana admin nyaa tidur hahahahaha
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# innalillahi terkejut terkadang gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# gempa beneran kencang berasa efek mikirin rumus matematika
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# rick halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# bumi utc sekotong indonesia felt keras merasakan mataram
# positif: 0
# negatif: 0
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# terbangun gempa mayan bikin dag dig dug serr gempa
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# bocil rewel bat disusul gempa
# rewel
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# cari info gempa akun apasi
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa pls
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# dom jam segini gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# dilaporkan pengguna aplikasi earthquake network laporan
# positif: 0
# negatif: 0
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa subuh
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# rubuh beneran gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# kebiasaan tidur pake baju sekalinya gempa terbangun pake selimut
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# dibangunin gempa kencang sat set sat set
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# beneran gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# ketiga kalinya semenjak tinggal bali gempa pagipagi jam segini reflek lari memast
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# berguncang alloh gempa astaghfirullah lumayan lombok
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# dibangunin gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# terkejut mimpi gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# dapatkan app lastquake gratis info gempa real time bagikan pengalaman berguncang
# gratis
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# gempa coklagi tidur nyenyak dibangunin bumi
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# berguncang gempa kencang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# sek sek lemes gemeteran gempa barusan
# lemes
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# aman berhenti gempa
# aman
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# nih gempa bkn sbentar
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa pembangun terbangun subuh
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# kagetkasur goyangnya kencang gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa info donk
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# berasa disentek kali gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# allahuakbar terkejut gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# alhamdulillah dibangunin subuhan gempa
# alhamdulillah
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# hj halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# lombok gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# lombok gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# mengagetkan gempa pagi buta
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa berguncang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# minggu merasakan gempa soresore minggu merasakan gempa subuhsubuh horor
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# horor
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# aman daerahnya terkena gempa
# aman
#  ['positif']
# gempa
#  ['negatif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# push rank gempa langsung gang gara gara fokus
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# terbangun gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# nyawa kedalaman kumpul gempa berguncang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# hwaaa gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# dibangunin sholat subuh gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# sumpah mimpi trnyata beneran gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# dimana gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# pagi pagi langsung dibangunin gempa disuruh terbangun sholat subuh mah buku buku langsung jatoh woy
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# bali gempa berguncang barusan cm detik kencang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# terbangun gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# terkejut pagi gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# kasur berguncang min titik gempa dimana
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa kakak terkejut seriusan
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# sumpah gempa dlam prepare alias celana melorot kabur
# gempa
#  ['negatif']
# kabur
#  ['negatif']
# kabur
#  ['negatif']
# positif: 0
# negatif: 3
# -----------------------------------------------------
# merasakan gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# dom lokasi gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# bnrean gempa huuu
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# kali pro terkadang gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# kle gempa berguncang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa lombok kuat akun bmkg update berguncang
# gempa
#  ['negatif']
# kuat
#  ['positif']
# positif: 1
# negatif: 1
# -----------------------------------------------------
# lepas sholat terkadang masuk dapur qodarullah gempa kucing kedalaman atap
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# terbangun gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# subuhnya terbangun iqomah pati gempa kiam
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# info gempa lombok barusan min terkadang susulan
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa dimana pusatnya
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# ptg halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# gempa berguncang lampu gantung rmh berguncang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# terbangun gempa berguncang
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa lho lumayan
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# blum tidur sie tpi teriak gempa gempa hahahaha terbangun jdinya
# gempa
#  ['negatif']
# gempa
#  ['negatif']
# positif: 0
# negatif: 2
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# lombok gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# selese nugas rebahin badan tibatiba kaca kamar bergetar lokasi ngira angin
# positif: 0
# negatif: 0
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# tidur gempa terbangun nyawa kekumpul yauda diam dikasur
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# woiii gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# ptg gempa dimana
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# ya gempa
# gempa
#  ['negatif']
# positif: 0
# negatif: 1
# -----------------------------------------------------
# halo bencana bot melaporkan dampak gempa sekitarmu silakan balas
# bencana
#  ['negatif']
# melaporkan
#  ['positif']
# dampak
#  ['negatif']
# gempa
#  ['negatif']
# balas
#  ['negatif']
# positif: 1
# negatif: 4
# -----------------------------------------------------
# Nilai rata-rata: -1.217
# Standar deviasi: 1.0439880267512651

# %%
labels, counts = np.unique(hasil, return_counts=True)
plt.bar(labels, counts, align='center')
plt.gca().set_xticks(labels)
plt.show()

# %%
df['sentiment'] = hasil
df.loc[df['sentiment'] == 0, 'sentiment'] = 'Neutral'
for i in range(7):
    df.loc[df['sentiment'] == i, 'sentiment'] = 'Positive'
    df.loc[df['sentiment'] == -i, 'sentiment'] = 'Negative'
df.head()
# Out:
#                                                tweet  \
# 0  @cattleyaishmn Halo, saya Bencana Bot. Untuk m...
# 1  Tbh kadang gue mikir pindah ibu kota tuh krn s...
# 2  Bisa ngga sih Tweet nya jangan info gempa teru...
# 3  Selamat pagii Sarapan roti boy dan white coffe...
# 4  @AdamPrakoso17 Gempa ora?\n\nInnalillahi \nAlh...
#
#                                          clean_tweet sentiment
# 0  halo bencana bot melaporkan dampak gempa sekit...  Negative
# 1  sejujurnya terkadang berpikir pindah kota sebe...   Neutral
# 2  tweet info gempa sekalikali infonya berguncang...   Neutral
# 3  selamat pagi sarapan roti terkadang white coff...  Negative
# 4         gempa innalillahi alhamdulillah aman keras  Positive

# %%
df.to_csv('gempa_tweet.csv', index=False)

# %% [markdown]
# Dari data yang kita dapatkan kata yang paling sering muncul yaitu gempa, terkadang, bergucang, lombok, bencana.
# Dari banyak kata yang muncul didapatkannya distribusi bigram yang mana didapatkan hasil yaitu (dampak, gempa), (halo, bencana), (gempa, sekitarmu), (silakan, balas), (sekitarmu, silakan) yang mana dari bigram dan juga banyak data yang keluar dapat disimpulkan bahwa dari topik gempa ini yang sering dibicarakan iyalah pelaporan terhadap bot halo bencana melalui twitter dan juga tentang dampak terjadinya gempa.
# Dari data tersebut juga dilakukan sentiment analisis yang mana hasilnya dapat disimpulkan bahwa tweet tentang gempa lebih menuju ke arah yang negatif dikarenakan memiliki nilai rata rata perhitungan antara positif dan negatif berada pada ngka -1.217 dan juga pada grafik yang yang telah dibuat tingginya nilai sentiment pada sisi negatif yaitu pada angka -1, -2, dan -3 yang mana pada angka -1 merupakan yang terbanyak dari semua bagian yang ada, untuk bagian -3, -2, -1, dan juga 0 memiliki nilai yang lebih dari 200 dan yang lainnya memiliki nilai yang kecil yaitu dibawah 100.
